# %%
import pandas as pd

# Load the data
df = pd.read_excel('/Users/jinnanut/Library/Mobile Documents/com~apple~CloudDocs/NUT/Exeter University/Master/Term 3/BEMM466 Business Project/Dissertation/Data/AmazonData.xlsx')
df['date'] = pd.to_datetime(df['date'])

# Get unique categories
categories = df['category'].unique()

# Create a dictionary to hold results
category_data = {}

# Define a 5-week test window
test_window = pd.Timedelta(weeks=5)

# Loop over each category
for cat in categories:
    print(f"\nProcessing category: {cat}")
    
    # Filter and resample weekly
    df_cat = df[df["category"] == cat].copy()
    df_cat = df_cat.set_index('date').sort_index()
    df_cat = df_cat[["quantity"]].resample('W').sum()
    
    # Initialize storage
    category_data[cat] = {"full": df_cat}
    
    # Walk-forward parameters
    start_train = pd.Timestamp("2019-01-01")
    end_of_data = df_cat.index.max()

    split_idx = 1
    # Start testing after 1 year of training data
    test_start = start_train + pd.Timedelta(weeks=52)
    test_end = test_start + test_window - pd.Timedelta(days=1)

    while test_end <= end_of_data:
        train_start = start_train
        train_end = test_start - pd.Timedelta(days=1)

        train_data = df_cat.loc[train_start:train_end]
        test_data = df_cat.loc[test_start:test_end]

        if train_data.empty or test_data.empty:
            print(f"  Skipping split {split_idx}: empty train or test")
        else:
            category_data[cat][f"train_{split_idx}"] = train_data
            category_data[cat][f"test_{split_idx}"] = test_data
            print(f"  Split {split_idx}: "
                  f"Train = {train_start.date()} to {train_end.date()}, "
                  f"Test = {test_start.date()} to {test_end.date()}")

        # Move test window forward by 5 weeks
        test_start += test_window
        test_end = test_start + test_window - pd.Timedelta(days=1)
        split_idx += 1

# Preview one category’s data
sample_cat = categories[0]
print(f"\nPreview for category '{sample_cat}':")
print(category_data[sample_cat]["full"].head())
# Out:
# Processing category: Appliances
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Beauty & Grooming
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Books
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Computing
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Entertainment
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Health & Sports
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Home & Living
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Kids & Baby
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Men's Fashion
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Mobiles & Tablets
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Others
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: School & Education
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Soghaat
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Superstore
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Processing category: Women's Fashion
#   Skipping split 1: empty train or test
#   Skipping split 2: empty train or test
#   Skipping split 3: empty train or test
#   Skipping split 4: empty train or test
#   Skipping split 5: empty train or test
#   Skipping split 6: empty train or test
#   Skipping split 7: empty train or test
#   Skipping split 8: empty train or test
#   Split 9: Train = 2019-01-01 to 2020-10-05, Test = 2020-10-06 to 2020-11-09
#   Split 10: Train = 2019-01-01 to 2020-11-09, Test = 2020-11-10 to 2020-12-14
#   Split 11: Train = 2019-01-01 to 2020-12-14, Test = 2020-12-15 to 2021-01-18
#   Split 12: Train = 2019-01-01 to 2021-01-18, Test = 2021-01-19 to 2021-02-22
#   Split 13: Train = 2019-01-01 to 2021-02-22, Test = 2021-02-23 to 2021-03-29
#   Split 14: Train = 2019-01-01 to 2021-03-29, Test = 2021-03-30 to 2021-05-03
#   Split 15: Train = 2019-01-01 to 2021-05-03, Test = 2021-05-04 to 2021-06-07
#   Split 16: Train = 2019-01-01 to 2021-06-07, Test = 2021-06-08 to 2021-07-12
#   Split 17: Train = 2019-01-01 to 2021-07-12, Test = 2021-07-13 to 2021-08-16
#   Split 18: Train = 2019-01-01 to 2021-08-16, Test = 2021-08-17 to 2021-09-20
#
# Preview for category 'Appliances':
#             quantity
# date
# 2020-10-04       180
# 2020-10-11       329
# 2020-10-18       338
# 2020-10-25       231
# 2020-11-01       246

# %% [markdown]
# # Applying Machine Learning with Monte Carlo Simulation with Case Study

# %% [markdown]
# ### Import Essential Tools

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Find Seasonal Index & Deseasonalize

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create dictionary to store seasonality results
seasonality_results = {}

for cat in categories:
    print(f"\nProcessing seasonal index for: {cat}")

    if cat not in category_data:
        print(f"  Skipping {cat}: no data.")
        continue

    seasonality_results[cat] = {}

    for key in category_data[cat]:
        if not key.startswith("train_"):
            continue

        train_df = category_data[cat][key].copy()

        if train_df.empty:
            print(f"  Skipping {cat} - {key}: empty train data.")
            continue

        # === Step 1: Extract ISO week number (1–52) ===
        train_df["week"] = train_df.index.isocalendar().week
        train_df["year"] = train_df.index.isocalendar().year

        # === Step 2: Compute weekly seasonal index (smoothed) ===
        overall_avg = train_df["quantity"].mean()
        weekly_avg = train_df.groupby("week")["quantity"].mean()

        # Smooth with rolling mean (handles noise better)
        weekly_avg_smooth = weekly_avg.rolling(3, center=True, min_periods=1).mean()

        # Normalize so seasonal index has mean = 1
        seasonal_index = weekly_avg_smooth / weekly_avg_smooth.mean()

        # Debug plot (optional: pick one case to visualize)
        if cat == categories[0] and key == "train_1":
            seasonal_index.plot(title=f"Smoothed Seasonal Index - {cat} - {key}")
            plt.grid(True)
            plt.show()

        # === Step 3: Map seasonal index back to train data ===
        train_df["seasonal_index"] = train_df["week"].map(seasonal_index)

        # === Step 4: Deseasonalize ===
        train_df["deseasonalized"] = (
            train_df["quantity"] / train_df["seasonal_index"].replace(0, np.nan)
        )
        train_df.dropna(subset=["deseasonalized"], inplace=True)

        # === Save results ===
        seasonality_results[cat][key] = {
            "seasonal_index": seasonal_index,
            "deseasonalized_train": train_df
        }

        print(f"  Done {cat} - {key}: {len(train_df)} weekly points deseasonalized.")
# Out:
# Processing seasonal index for: Appliances
#   Done Appliances - train_9: 1 weekly points deseasonalized.
#   Done Appliances - train_10: 6 weekly points deseasonalized.
#   Done Appliances - train_11: 11 weekly points deseasonalized.
#   Done Appliances - train_12: 16 weekly points deseasonalized.
#   Done Appliances - train_13: 21 weekly points deseasonalized.
#   Done Appliances - train_14: 26 weekly points deseasonalized.
#   Done Appliances - train_15: 31 weekly points deseasonalized.
#   Done Appliances - train_16: 36 weekly points deseasonalized.
#   Done Appliances - train_17: 41 weekly points deseasonalized.
#   Done Appliances - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Beauty & Grooming
#   Done Beauty & Grooming - train_9: 1 weekly points deseasonalized.
#   Done Beauty & Grooming - train_10: 6 weekly points deseasonalized.
#   Done Beauty & Grooming - train_11: 11 weekly points deseasonalized.
#   Done Beauty & Grooming - train_12: 16 weekly points deseasonalized.
#   Done Beauty & Grooming - train_13: 21 weekly points deseasonalized.
#   Done Beauty & Grooming - train_14: 26 weekly points deseasonalized.
#   Done Beauty & Grooming - train_15: 31 weekly points deseasonalized.
#   Done Beauty & Grooming - train_16: 36 weekly points deseasonalized.
#   Done Beauty & Grooming - train_17: 41 weekly points deseasonalized.
#   Done Beauty & Grooming - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Books
#   Done Books - train_9: 1 weekly points deseasonalized.
#   Done Books - train_10: 6 weekly points deseasonalized.
#   Done Books - train_11: 11 weekly points deseasonalized.
#   Done Books - train_12: 16 weekly points deseasonalized.
#   Done Books - train_13: 21 weekly points deseasonalized.
#   Done Books - train_14: 26 weekly points deseasonalized.
#   Done Books - train_15: 31 weekly points deseasonalized.
#   Done Books - train_16: 36 weekly points deseasonalized.
#   Done Books - train_17: 41 weekly points deseasonalized.
#   Done Books - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Computing
#   Done Computing - train_9: 1 weekly points deseasonalized.
#   Done Computing - train_10: 6 weekly points deseasonalized.
#   Done Computing - train_11: 11 weekly points deseasonalized.
#   Done Computing - train_12: 16 weekly points deseasonalized.
#   Done Computing - train_13: 21 weekly points deseasonalized.
#   Done Computing - train_14: 26 weekly points deseasonalized.
#   Done Computing - train_15: 31 weekly points deseasonalized.
#   Done Computing - train_16: 36 weekly points deseasonalized.
#   Done Computing - train_17: 41 weekly points deseasonalized.
#   Done Computing - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Entertainment
#   Done Entertainment - train_9: 1 weekly points deseasonalized.
#   Done Entertainment - train_10: 6 weekly points deseasonalized.
#   Done Entertainment - train_11: 11 weekly points deseasonalized.
#   Done Entertainment - train_12: 16 weekly points deseasonalized.
#   Done Entertainment - train_13: 21 weekly points deseasonalized.
#   Done Entertainment - train_14: 26 weekly points deseasonalized.
#   Done Entertainment - train_15: 31 weekly points deseasonalized.
#   Done Entertainment - train_16: 36 weekly points deseasonalized.
#   Done Entertainment - train_17: 41 weekly points deseasonalized.
#   Done Entertainment - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Health & Sports
#   Done Health & Sports - train_9: 1 weekly points deseasonalized.
#   Done Health & Sports - train_10: 6 weekly points deseasonalized.
#   Done Health & Sports - train_11: 11 weekly points deseasonalized.
#   Done Health & Sports - train_12: 16 weekly points deseasonalized.
#   Done Health & Sports - train_13: 21 weekly points deseasonalized.
#   Done Health & Sports - train_14: 26 weekly points deseasonalized.
#   Done Health & Sports - train_15: 31 weekly points deseasonalized.
#   Done Health & Sports - train_16: 36 weekly points deseasonalized.
#   Done Health & Sports - train_17: 41 weekly points deseasonalized.
#   Done Health & Sports - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Home & Living
#   Done Home & Living - train_9: 1 weekly points deseasonalized.
#   Done Home & Living - train_10: 6 weekly points deseasonalized.
#   Done Home & Living - train_11: 11 weekly points deseasonalized.
#   Done Home & Living - train_12: 16 weekly points deseasonalized.
#   Done Home & Living - train_13: 21 weekly points deseasonalized.
#   Done Home & Living - train_14: 26 weekly points deseasonalized.
#   Done Home & Living - train_15: 31 weekly points deseasonalized.
#   Done Home & Living - train_16: 36 weekly points deseasonalized.
#   Done Home & Living - train_17: 41 weekly points deseasonalized.
#   Done Home & Living - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Kids & Baby
#   Done Kids & Baby - train_9: 1 weekly points deseasonalized.
#   Done Kids & Baby - train_10: 6 weekly points deseasonalized.
#   Done Kids & Baby - train_11: 11 weekly points deseasonalized.
#   Done Kids & Baby - train_12: 16 weekly points deseasonalized.
#   Done Kids & Baby - train_13: 21 weekly points deseasonalized.
#   Done Kids & Baby - train_14: 26 weekly points deseasonalized.
#   Done Kids & Baby - train_15: 31 weekly points deseasonalized.
#   Done Kids & Baby - train_16: 36 weekly points deseasonalized.
#   Done Kids & Baby - train_17: 41 weekly points deseasonalized.
#   Done Kids & Baby - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Men's Fashion
#   Done Men's Fashion - train_9: 1 weekly points deseasonalized.
#   Done Men's Fashion - train_10: 6 weekly points deseasonalized.
#   Done Men's Fashion - train_11: 11 weekly points deseasonalized.
#   Done Men's Fashion - train_12: 16 weekly points deseasonalized.
#   Done Men's Fashion - train_13: 21 weekly points deseasonalized.
#   Done Men's Fashion - train_14: 26 weekly points deseasonalized.
#   Done Men's Fashion - train_15: 31 weekly points deseasonalized.
#   Done Men's Fashion - train_16: 36 weekly points deseasonalized.
#   Done Men's Fashion - train_17: 41 weekly points deseasonalized.
#   Done Men's Fashion - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Mobiles & Tablets
#   Done Mobiles & Tablets - train_9: 1 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_10: 6 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_11: 11 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_12: 16 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_13: 21 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_14: 26 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_15: 31 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_16: 36 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_17: 41 weekly points deseasonalized.
#   Done Mobiles & Tablets - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Others
#   Done Others - train_9: 1 weekly points deseasonalized.
#   Done Others - train_10: 6 weekly points deseasonalized.
#   Done Others - train_11: 11 weekly points deseasonalized.
#   Done Others - train_12: 16 weekly points deseasonalized.
#   Done Others - train_13: 21 weekly points deseasonalized.
#   Done Others - train_14: 26 weekly points deseasonalized.
#   Done Others - train_15: 31 weekly points deseasonalized.
#   Done Others - train_16: 36 weekly points deseasonalized.
#   Done Others - train_17: 41 weekly points deseasonalized.
#   Done Others - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: School & Education
#   Done School & Education - train_9: 1 weekly points deseasonalized.
#   Done School & Education - train_10: 6 weekly points deseasonalized.
#   Done School & Education - train_11: 11 weekly points deseasonalized.
#   Done School & Education - train_12: 16 weekly points deseasonalized.
#   Done School & Education - train_13: 21 weekly points deseasonalized.
#   Done School & Education - train_14: 26 weekly points deseasonalized.
#   Done School & Education - train_15: 31 weekly points deseasonalized.
#   Done School & Education - train_16: 36 weekly points deseasonalized.
#   Done School & Education - train_17: 41 weekly points deseasonalized.
#   Done School & Education - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Soghaat
#   Done Soghaat - train_9: 1 weekly points deseasonalized.
#   Done Soghaat - train_10: 6 weekly points deseasonalized.
#   Done Soghaat - train_11: 11 weekly points deseasonalized.
#   Done Soghaat - train_12: 16 weekly points deseasonalized.
#   Done Soghaat - train_13: 21 weekly points deseasonalized.
#   Done Soghaat - train_14: 26 weekly points deseasonalized.
#   Done Soghaat - train_15: 31 weekly points deseasonalized.
#   Done Soghaat - train_16: 36 weekly points deseasonalized.
#   Done Soghaat - train_17: 41 weekly points deseasonalized.
#   Done Soghaat - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Superstore
#   Done Superstore - train_9: 1 weekly points deseasonalized.
#   Done Superstore - train_10: 6 weekly points deseasonalized.
#   Done Superstore - train_11: 11 weekly points deseasonalized.
#   Done Superstore - train_12: 16 weekly points deseasonalized.
#   Done Superstore - train_13: 21 weekly points deseasonalized.
#   Done Superstore - train_14: 26 weekly points deseasonalized.
#   Done Superstore - train_15: 31 weekly points deseasonalized.
#   Done Superstore - train_16: 36 weekly points deseasonalized.
#   Done Superstore - train_17: 41 weekly points deseasonalized.
#   Done Superstore - train_18: 46 weekly points deseasonalized.
#
# Processing seasonal index for: Women's Fashion
#   Done Women's Fashion - train_9: 1 weekly points deseasonalized.
#   Done Women's Fashion - train_10: 6 weekly points deseasonalized.
#   Done Women's Fashion - train_11: 11 weekly points deseasonalized.
#   Done Women's Fashion - train_12: 16 weekly points deseasonalized.
#   Done Women's Fashion - train_13: 21 weekly points deseasonalized.
#   Done Women's Fashion - train_14: 26 weekly points deseasonalized.
#   Done Women's Fashion - train_15: 31 weekly points deseasonalized.
#   Done Women's Fashion - train_16: 36 weekly points deseasonalized.
#   Done Women's Fashion - train_17: 41 weekly points deseasonalized.
#   Done Women's Fashion - train_18: 46 weekly points deseasonalized.

# %% [markdown]
# ### 2. Fit Trend Models & Select the Best model

# %%
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import pandas as pd

trend_results = {}

for cat in seasonality_results:
    print(f"\nFitting candidate models for category: {cat}")
    trend_results[cat] = {}

    for train_key in seasonality_results[cat]:
        if not train_key.startswith("train_"):
            continue

        train_df = seasonality_results[cat][train_key]["deseasonalized_train"].copy()

        if len(train_df) < 10:
            print(f"  Skipping {cat} - {train_key}: too few points ({len(train_df)})")
            continue

        y = train_df["deseasonalized"].values
        X_time = np.arange(len(y)).reshape(-1, 1)

        candidate_models = {}

        # === Linear Regression Trend ===
        lin = LinearRegression()
        lin.fit(X_time, y)
        y_pred_lin = lin.predict(X_time)
        candidate_models["linear"] = {
            "in_sample_pred": y_pred_lin,
            "rmse": mean_squared_error(y, y_pred_lin, squared=False),
            "mae": mean_absolute_error(y, y_pred_lin),
            "model": lin,
            "forecast_func": lambda horizon: lin.predict(np.arange(len(y), len(y)+horizon).reshape(-1, 1))
        }

        # === Polynomial Trend (deg 2) ===
        poly2 = PolynomialFeatures(2)
        X_poly2 = poly2.fit_transform(X_time)
        lin_poly = LinearRegression()
        lin_poly.fit(X_poly2, y)
        y_pred_poly = lin_poly.predict(X_poly2)
        candidate_models["poly2"] = {
            "in_sample_pred": y_pred_poly,
            "rmse": mean_squared_error(y, y_pred_poly, squared=False),
            "mae": mean_absolute_error(y, y_pred_poly),
            "model": lin_poly,
            "transformer": poly2,
            "forecast_func": lambda horizon: lin_poly.predict(poly2.transform(
                np.arange(len(y), len(y)+horizon).reshape(-1, 1)))
        }

        # === Holt-Winters Exponential Smoothing ===
        try:
            hw = ExponentialSmoothing(train_df["deseasonalized"],
                                      trend="add", seasonal=None).fit()
            y_pred_hw = hw.fittedvalues
            candidate_models["holt_winters"] = {
                "in_sample_pred": y_pred_hw.values,
                "rmse": mean_squared_error(y, y_pred_hw, squared=False),
                "mae": mean_absolute_error(y, y_pred_hw),
                "model": hw,
                "forecast_func": lambda horizon: hw.forecast(horizon).values
            }
        except Exception as e:
            print(f"    Holt-Winters failed: {e}")

        # === XGBoost with lag features ===
        train_df["lag_1"] = train_df["deseasonalized"].shift(1)
        train_df["lag_2"] = train_df["deseasonalized"].shift(2)
        train_df.dropna(inplace=True)
        y_ml = train_df["deseasonalized"].values
        X_ml = train_df[["lag_1", "lag_2"]].values

        xgb = XGBRegressor(objective="reg:squarederror", n_estimators=200,
                           learning_rate=0.1, max_depth=3, random_state=42, verbosity=0)
        xgb.fit(X_ml, y_ml)
        y_pred_xgb = xgb.predict(X_ml)

        def xgb_forecast(horizon):
            last_vals = list(train_df["deseasonalized"][-2:])
            forecast_vals = []
            for _ in range(horizon):
                x_next = np.array([last_vals[-1], last_vals[-2]]).reshape(1, -1)
                y_next = xgb.predict(x_next)[0]
                forecast_vals.append(y_next)
                last_vals.append(y_next)
            return np.array(forecast_vals)

        candidate_models["xgboost"] = {
            "in_sample_pred": y_pred_xgb,
            "rmse": mean_squared_error(y_ml, y_pred_xgb, squared=False),
            "mae": mean_absolute_error(y_ml, y_pred_xgb),
            "model": xgb,
            "forecast_func": xgb_forecast
        }

        # === Select best model by RMSE ===
        best_model_name = min(candidate_models, key=lambda k: candidate_models[k]["rmse"])
        best_model = candidate_models[best_model_name]

        forecast_horizon = 5
        forecast_vals = best_model["forecast_func"](forecast_horizon)

        trend_results[cat][train_key] = {
            "best_model": best_model_name,
            "model": best_model["model"],
            "in_sample_pred": best_model["in_sample_pred"],
            "residuals": y[-len(best_model["in_sample_pred"]):] - best_model["in_sample_pred"],
            "forecast": forecast_vals,
            "rmse": best_model["rmse"],
            "mae": best_model["mae"]
        }

        print(f"  {train_key}: Best = {best_model_name}, RMSE = {best_model['rmse']:.2f}, "
              f"MAE = {best_model['mae']:.2f}, Forecast Horizon = {forecast_horizon} weeks")
# Out:
# Fitting candidate models for category: Appliances
#   Skipping Appliances - train_9: too few points (1)
#   Skipping Appliances - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.04, MAE = 0.03, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.38, MAE = 0.30, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 1.80, MAE = 1.41, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 8.87, MAE = 6.78, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 9.63, MAE = 7.74, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 20.75, MAE = 15.86, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 26.53, MAE = 20.88, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 32.24, MAE = 24.41, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Beauty & Grooming
#   Skipping Beauty & Grooming - train_9: too few points (1)
#   Skipping Beauty & Grooming - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.00, MAE = 0.00, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.96, MAE = 0.78, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 2.88, MAE = 2.43, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 8.28, MAE = 6.49, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 16.83, MAE = 13.20, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 17.99, MAE = 13.59, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 24.64, MAE = 18.71, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 23.09, MAE = 18.34, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Books
#   Skipping Books - train_9: too few points (1)
#   Skipping Books - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.00, MAE = 0.00, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.06, MAE = 0.05, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 0.15, MAE = 0.12, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 0.32, MAE = 0.27, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 0.25, MAE = 0.19, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 0.67, MAE = 0.52, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 0.90, MAE = 0.73, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 1.69, MAE = 1.40, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Computing
#   Skipping Computing - train_9: too few points (1)
#   Skipping Computing - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.01, MAE = 0.01, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 1.20, MAE = 1.01, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 1.39, MAE = 1.11, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 3.79, MAE = 2.64, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 7.22, MAE = 5.66, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 8.08, MAE = 6.15, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 10.04, MAE = 7.61, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 12.32, MAE = 9.39, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Entertainment
#   Skipping Entertainment - train_9: too few points (1)
#   Skipping Entertainment - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.15, MAE = 0.14, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.57, MAE = 0.48, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 2.41, MAE = 2.09, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 3.46, MAE = 2.96, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 11.70, MAE = 9.42, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 7.25, MAE = 5.86, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 15.74, MAE = 12.53, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 26.03, MAE = 20.31, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Health & Sports
#   Skipping Health & Sports - train_9: too few points (1)
#   Skipping Health & Sports - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.00, MAE = 0.00, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.05, MAE = 0.04, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 0.24, MAE = 0.20, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 0.33, MAE = 0.28, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 2.89, MAE = 2.22, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 4.79, MAE = 3.96, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 8.97, MAE = 6.80, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 9.45, MAE = 7.53, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Home & Living
#   Skipping Home & Living - train_9: too few points (1)
#   Skipping Home & Living - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.00, MAE = 0.00, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 1.88, MAE = 1.63, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 1.12, MAE = 0.82, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 2.97, MAE = 2.22, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 3.05, MAE = 2.42, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 6.13, MAE = 4.77, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 9.41, MAE = 7.10, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 16.09, MAE = 12.37, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Kids & Baby
#   Skipping Kids & Baby - train_9: too few points (1)
#   Skipping Kids & Baby - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.01, MAE = 0.01, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.07, MAE = 0.05, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 0.50, MAE = 0.40, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 3.98, MAE = 3.21, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 3.93, MAE = 3.28, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 5.99, MAE = 5.09, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 7.03, MAE = 5.94, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 6.80, MAE = 5.75, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Men's Fashion
#   Skipping Men's Fashion - train_9: too few points (1)
#   Skipping Men's Fashion - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.02, MAE = 0.02, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 4.32, MAE = 3.38, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 10.22, MAE = 7.90, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 23.43, MAE = 17.68, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 32.04, MAE = 24.34, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 31.73, MAE = 24.60, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 26.00, MAE = 20.11, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 29.21, MAE = 23.92, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Mobiles & Tablets
#   Skipping Mobiles & Tablets - train_9: too few points (1)
#   Skipping Mobiles & Tablets - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.13, MAE = 0.10, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 2.28, MAE = 1.90, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 5.14, MAE = 3.67, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 6.17, MAE = 4.56, Forecast Horizon = 5 weeks
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
#   train_15: Best = xgboost, RMSE = 16.79, MAE = 12.50, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 27.65, MAE = 20.77, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 32.61, MAE = 24.53, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 53.38, MAE = 40.27, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Others
#   Skipping Others - train_9: too few points (1)
#   Skipping Others - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.02, MAE = 0.01, Forecast Horizon = 5 weeks
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
#   train_12: Best = xgboost, RMSE = 0.20, MAE = 0.16, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 0.54, MAE = 0.44, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 4.15, MAE = 3.09, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 38.80, MAE = 30.60, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 42.64, MAE = 33.41, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 80.84, MAE = 64.05, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 89.96, MAE = 71.64, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: School & Education
#   Skipping School & Education - train_9: too few points (1)
#   Skipping School & Education - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.00, MAE = 0.00, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.01, MAE = 0.01, Forecast Horizon = 5 weeks
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
#   train_13: Best = xgboost, RMSE = 0.16, MAE = 0.12, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 0.24, MAE = 0.20, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 0.57, MAE = 0.47, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 0.98, MAE = 0.74, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 1.37, MAE = 1.06, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 1.58, MAE = 1.22, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Soghaat
#   Skipping Soghaat - train_9: too few points (1)
#   Skipping Soghaat - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.03, MAE = 0.02, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 0.18, MAE = 0.15, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 1.00, MAE = 0.76, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 1.58, MAE = 1.29, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 4.65, MAE = 3.82, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 6.46, MAE = 5.01, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 13.06, MAE = 10.28, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 11.24, MAE = 8.45, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Superstore
#   Skipping Superstore - train_9: too few points (1)
#   Skipping Superstore - train_10: too few points (6)
#   train_11: Best = xgboost, RMSE = 0.02, MAE = 0.01, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 1.38, MAE = 1.15, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 3.06, MAE = 2.35, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 11.30, MAE = 9.31, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 21.05, MAE = 17.01, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 36.37, MAE = 28.20, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 53.13, MAE = 40.55, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 67.19, MAE = 50.91, Forecast Horizon = 5 weeks
#
# Fitting candidate models for category: Women's Fashion
#   Skipping Women's Fashion - train_9: too few points (1)
#   Skipping Women's Fashion - train_10: too few points (6)
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/statsmodels/tsa/holtwinters/model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(
#   train_11: Best = xgboost, RMSE = 0.06, MAE = 0.05, Forecast Horizon = 5 weeks
#   train_12: Best = xgboost, RMSE = 1.61, MAE = 1.29, Forecast Horizon = 5 weeks
#   train_13: Best = xgboost, RMSE = 1.36, MAE = 1.03, Forecast Horizon = 5 weeks
#   train_14: Best = xgboost, RMSE = 5.86, MAE = 4.60, Forecast Horizon = 5 weeks
#   train_15: Best = xgboost, RMSE = 8.18, MAE = 6.51, Forecast Horizon = 5 weeks
#   train_16: Best = xgboost, RMSE = 7.61, MAE = 6.05, Forecast Horizon = 5 weeks
#   train_17: Best = xgboost, RMSE = 20.37, MAE = 16.29, Forecast Horizon = 5 weeks
#   train_18: Best = xgboost, RMSE = 31.31, MAE = 24.72, Forecast Horizon = 5 weeks

# %% [markdown]
# ### 3. Generate Residual-Based Noise for Monte Carlo

# %%
import numpy as np

# Create dictionary to store Monte Carlo inputs
montecarlo_inputs = {}

# Parameters
n_simulations = 1000
forecast_len = 5
block_size = 3  # block bootstrap length

for cat in trend_results:
    print(f"\nGenerating improved Monte Carlo inputs for category: {cat}")
    montecarlo_inputs[cat] = {}

    for train_key in trend_results[cat]:
        if train_key not in seasonality_results[cat]:
            print(f"  Skipping {train_key}: missing seasonality data.")
            continue

        residuals = trend_results[cat][train_key]["residuals"]
        base_forecast = trend_results[cat][train_key]["forecast"]

        if len(residuals) < 10:
            print(f"  Skipping {train_key}: too few residuals")
            continue

        # === Step 1: Clean residuals (remove >3 std outliers)
        resid_mean, resid_std = residuals.mean(), residuals.std()
        cleaned_resid = residuals[np.abs(residuals - resid_mean) < 3 * resid_std]

        # === Step 2: Block bootstrap
        blocks = []
        for _ in range(n_simulations):
            resampled = []
            while len(resampled) < forecast_len:
                start = np.random.randint(0, len(cleaned_resid) - block_size + 1)
                block = cleaned_resid[start:start + block_size]
                resampled.extend(block)
            blocks.append(resampled[:forecast_len])
        boot_noise = np.array(blocks).T  # shape (forecast_len, n_simulations)

        # === Step 3: Optionally scale noise by forecast magnitude
        forecast_scale = np.maximum(base_forecast, 1e-3)  # avoid zero-div
        scaled_noise = boot_noise * (forecast_scale.mean() / np.std(cleaned_resid))

        # === Step 4: Store
        montecarlo_inputs[cat][train_key] = {
            "bootstrapped_noise": scaled_noise,
            "base_forecast": base_forecast,
            "residuals": cleaned_resid
        }

        print(f"  {train_key}: residuals used = {len(cleaned_resid)}, "
              f"noise shape = {scaled_noise.shape}")
# Out:
# Generating improved Monte Carlo inputs for category: Appliances
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Beauty & Grooming
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Books
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Computing
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Entertainment
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Health & Sports
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Home & Living
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Kids & Baby
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Men's Fashion
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Mobiles & Tablets
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Others
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: School & Education
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Soghaat
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Superstore
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)
#
# Generating improved Monte Carlo inputs for category: Women's Fashion
#   Skipping train_11: too few residuals
#   train_12: residuals used = 14, noise shape = (5, 1000)
#   train_13: residuals used = 19, noise shape = (5, 1000)
#   train_14: residuals used = 24, noise shape = (5, 1000)
#   train_15: residuals used = 29, noise shape = (5, 1000)
#   train_16: residuals used = 34, noise shape = (5, 1000)
#   train_17: residuals used = 39, noise shape = (5, 1000)
#   train_18: residuals used = 44, noise shape = (5, 1000)

# %% [markdown]
# ### 4. Reintroduce Seasonality

# %%
import numpy as np

# Create a dictionary to store simulation results
simulated_demands = {}

for cat in trend_results:
    print(f"\nReintroducing seasonality for category: {cat}")
    simulated_demands[cat] = {}

    for train_key in trend_results[cat]:
        # Ensure matching seasonal + simulation input exists
        if train_key not in seasonality_results[cat] or train_key not in montecarlo_inputs[cat]:
            print(f"  Skipping {train_key}: missing seasonality or simulation input")
            continue

        # Fetch base forecast and bootstrapped noise
        base_forecast = np.array(montecarlo_inputs[cat][train_key]["base_forecast"])  # shape (5,)
        noise_matrix = montecarlo_inputs[cat][train_key]["bootstrapped_noise"]        # shape (5, n_simulations)

        forecast_len = len(base_forecast)
        
        # === Find the last training week number ===
        last_train_week = seasonality_results[cat][train_key]["deseasonalized_train"].index[-1].isocalendar().week

        # === Build seasonal factors for the next forecast_len weeks ===
        future_weeks = [(last_train_week + i) % 52 or 52 for i in range(1, forecast_len + 1)]
        seasonal_index = seasonality_results[cat][train_key]["seasonal_index"]
        seasonal_factors = seasonal_index.reindex(future_weeks).fillna(1.0).values.reshape(-1, 1)

        # === Step 1: Simulate deseasonalized values ===
        simulated_deseasonalized = base_forecast.reshape(-1, 1) + noise_matrix

        # === Step 2: Reintroduce seasonality ===
        simulated_with_seasonality = simulated_deseasonalized * seasonal_factors

        # === Step 3: Store results ===
        simulated_demands[cat][train_key] = {
            "simulated_demand": simulated_with_seasonality,  # shape: (5, n_simulations)
            "seasonal_factors": seasonal_factors,
            "forecast_mean": simulated_with_seasonality.mean(axis=1),
            "lower_bound": np.percentile(simulated_with_seasonality, 10, axis=1),  # P10
            "upper_bound": np.percentile(simulated_with_seasonality, 90, axis=1)   # P90
        }

        print(f"  {train_key}: simulated shape = {simulated_with_seasonality.shape}, "
              f"weeks forecasted = {future_weeks}")
# Out:
# Reintroducing seasonality for category: Appliances
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Beauty & Grooming
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Books
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Computing
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Entertainment
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Health & Sports
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Home & Living
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Kids & Baby
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Men's Fashion
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Mobiles & Tablets
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Others
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: School & Education
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Soghaat
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Superstore
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]
#
# Reintroducing seasonality for category: Women's Fashion
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), weeks forecasted = [33, 34, 35, 36, 37]

# %% [markdown]
# ### 5. Aggregate & Summarize Simulated Demand

# %%
import numpy as np
import pandas as pd

simulated_demands = {}

for cat in trend_results:
    print(f"\nAggregating simulated weekly demand for category: {cat}")
    simulated_demands[cat] = {}

    for train_key in trend_results[cat]:
        if train_key not in seasonality_results[cat] or train_key not in montecarlo_inputs[cat]:
            print(f"  Skipping {train_key}: missing seasonality or simulation input")
            continue

        base_forecast = np.array(montecarlo_inputs[cat][train_key]["base_forecast"])  
        noise_matrix = montecarlo_inputs[cat][train_key]["bootstrapped_noise"]

        forecast_len = len(base_forecast)

        # Align using real forecast dates
        last_train_date = seasonality_results[cat][train_key]["deseasonalized_train"].index[-1]
        forecast_dates = [last_train_date + pd.Timedelta(weeks=i) for i in range(1, forecast_len + 1)]
        future_weeks = [d.isocalendar().week for d in forecast_dates]

        seasonal_index = seasonality_results[cat][train_key]["seasonal_index"]
        seasonal_factors = seasonal_index.reindex(future_weeks).fillna(1.0).values.reshape(-1, 1)

        # Simulate
        simulated_deseasonalized = base_forecast.reshape(-1, 1) + noise_matrix
        simulated_with_seasonality = simulated_deseasonalized * seasonal_factors

        # Summaries
        forecast_mean = simulated_with_seasonality.mean(axis=1)
        forecast_median = np.median(simulated_with_seasonality, axis=1)
        lower_bound = np.percentile(simulated_with_seasonality, 10, axis=1)
        upper_bound = np.percentile(simulated_with_seasonality, 90, axis=1)

        total_demand_per_sim = simulated_with_seasonality.sum(axis=0)
        coverage = np.mean([
            (lb <= val <= ub) for val, lb, ub in zip(forecast_mean, lower_bound, upper_bound)
        ])

        simulated_demands[cat][train_key] = {
            "dates": forecast_dates,
            "simulated_demand": simulated_with_seasonality,
            "forecast_mean": forecast_mean,
            "forecast_median": forecast_median,
            "lower_bound": lower_bound,
            "upper_bound": upper_bound,
            "coverage": coverage,
            "total_demand_distribution": total_demand_per_sim,
            "total_demand_mean": total_demand_per_sim.mean(),
            "total_demand_p10": np.percentile(total_demand_per_sim, 10),
            "total_demand_p90": np.percentile(total_demand_per_sim, 90)
        }

        print(f"  {train_key}: simulated shape = {simulated_with_seasonality.shape}, "
              f"total mean = {total_demand_per_sim.mean():,.0f}, "
              f"coverage ~ {coverage:.2f}, weeks forecasted = {future_weeks}")
# Out:
# Aggregating simulated weekly demand for category: Appliances
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 11,438, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 9,349, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 10,377, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 9,740, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 7,674, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 8,130, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 7,914, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Beauty & Grooming
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 7,926, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 7,201, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 6,213, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 5,816, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 6,590, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 8,018, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 6,174, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Books
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 256, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 208, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 197, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 193, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 219, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 230, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 217, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Computing
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 2,504, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 3,072, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 1,805, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 2,246, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 2,398, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 1,865, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 2,190, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Entertainment
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 4,057, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 3,748, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 3,445, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 3,355, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 4,539, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 3,833, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 3,435, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Health & Sports
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 1,402, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 1,641, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 1,527, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 2,064, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 2,218, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 2,870, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 2,620, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Home & Living
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 4,701, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 4,502, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 5,457, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 4,623, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 4,580, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 5,269, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 4,028, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Kids & Baby
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 2,378, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 2,054, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 2,306, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 1,916, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 2,145, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 2,365, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 2,156, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Men's Fashion
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 13,157, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 12,935, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 11,771, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 11,853, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 11,672, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 10,807, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 9,522, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Mobiles & Tablets
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 13,877, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 12,392, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 10,334, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 13,575, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 12,070, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 13,386, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 12,546, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Others
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 1,846, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 1,512, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 3,460, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 10,723, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 15,602, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 14,473, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 11,869, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: School & Education
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 151, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 196, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 278, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 450, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 411, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 377, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 386, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Soghaat
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 2,627, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 2,764, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 2,433, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 2,116, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 2,445, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 3,258, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 3,045, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Superstore
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 4,823, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 5,367, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 5,516, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 8,502, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 9,224, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 10,491, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 11,228, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]
#
# Aggregating simulated weekly demand for category: Women's Fashion
#   Skipping train_11: missing seasonality or simulation input
#   train_12: simulated shape = (5, 1000), total mean = 9,273, coverage ~ 1.00, weeks forecasted = [3, 4, 5, 6, 7]
#   train_13: simulated shape = (5, 1000), total mean = 6,494, coverage ~ 1.00, weeks forecasted = [8, 9, 10, 11, 12]
#   train_14: simulated shape = (5, 1000), total mean = 7,164, coverage ~ 1.00, weeks forecasted = [13, 14, 15, 16, 17]
#   train_15: simulated shape = (5, 1000), total mean = 7,621, coverage ~ 1.00, weeks forecasted = [18, 19, 20, 21, 22]
#   train_16: simulated shape = (5, 1000), total mean = 7,517, coverage ~ 1.00, weeks forecasted = [23, 24, 25, 26, 27]
#   train_17: simulated shape = (5, 1000), total mean = 8,788, coverage ~ 1.00, weeks forecasted = [28, 29, 30, 31, 32]
#   train_18: simulated shape = (5, 1000), total mean = 7,099, coverage ~ 1.00, weeks forecasted = [33, 34, 35, 36, 37]

# %% [markdown]
# ### 6. Ploting Graph to Analysis

# %%
import matplotlib.pyplot as plt
import pandas as pd

for cat in simulated_demands:
    print(f"\nCombining and plotting all splits for: {cat}")

    # Collect actuals and forecasts in lists
    actual_list = []
    mean_list = []
    p10_list = []
    p90_list = []

    for train_key in simulated_demands[cat]:
        if train_key not in seasonality_results[cat]:
            continue

        # === Actual demand ===
        train_df = seasonality_results[cat][train_key]["deseasonalized_train"]
        actual = train_df[["quantity"]].reset_index().rename(columns={"date": "date", "quantity": "actual"})
        actual_list.append(actual)

        # === Forecast summaries ===
        forecast_len = len(simulated_demands[cat][train_key]["forecast_mean"])
        last_actual_date = train_df.index[-1]
        forecast_dates = [last_actual_date + pd.Timedelta(weeks=i) for i in range(1, forecast_len + 1)]

        forecast_df = pd.DataFrame({
            "date": forecast_dates,
            "forecast_mean": simulated_demands[cat][train_key]["forecast_mean"],
            "p10": simulated_demands[cat][train_key]["lower_bound"],
            "p90": simulated_demands[cat][train_key]["upper_bound"]
        })
        mean_list.append(forecast_df[["date", "forecast_mean"]])
        p10_list.append(forecast_df[["date", "p10"]])
        p90_list.append(forecast_df[["date", "p90"]])

    # Combine all dataframes
    actual_df = pd.concat(actual_list, ignore_index=True)
    mean_df = pd.concat(mean_list, ignore_index=True)
    p10_df = pd.concat(p10_list, ignore_index=True)
    p90_df = pd.concat(p90_list, ignore_index=True)

    # Merge into a single dataframe
    combined_df = actual_df.merge(mean_df, on="date", how="outer") \
                           .merge(p10_df, on="date", how="outer") \
                           .merge(p90_df, on="date", how="outer")

    # Aggregate by date to remove duplicates
    combined_df = combined_df.groupby("date").agg({
        "actual": "first",
        "forecast_mean": "mean",
        "p10": "mean",
        "p90": "mean"
    }).reset_index().sort_values("date")

    # === Plot ===
    plt.figure(figsize=(14, 6))
    plt.plot(combined_df["date"], combined_df["actual"], label="Actual Demand",
             color="black", linestyle="--", marker="o", alpha=0.7)
    plt.plot(combined_df["date"], combined_df["forecast_mean"], label="Forecast Mean",
             color="tab:blue", linewidth=2)
    plt.fill_between(combined_df["date"], combined_df["p10"], combined_df["p90"],
                     color="tab:blue", alpha=0.2, label="80% Prediction Interval (P10–P90)")

    # Formatting
    plt.title(f"Combined 5-Week Forecast with Monte Carlo — {cat}")
    plt.xlabel("Date")
    plt.ylabel("Quantity")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Combining and plotting all splits for: Appliances
# Combining and plotting all splits for: Beauty & Grooming
# Combining and plotting all splits for: Books
# Combining and plotting all splits for: Computing
# Combining and plotting all splits for: Entertainment
# Combining and plotting all splits for: Health & Sports
# Combining and plotting all splits for: Home & Living
# Combining and plotting all splits for: Kids & Baby
# Combining and plotting all splits for: Men's Fashion
# Combining and plotting all splits for: Mobiles & Tablets
# Combining and plotting all splits for: Others
# Combining and plotting all splits for: School & Education
# Combining and plotting all splits for: Soghaat
# Combining and plotting all splits for: Superstore
# Combining and plotting all splits for: Women's Fashion

# %% [markdown]
# ### Export to Excel file

# %%
import pandas as pd

export_rows = []

for cat in simulated_demands:
    print(f"Exporting results for: {cat}")

    # Full actual demand series
    actual_series = category_data[cat]["full"]["quantity"]

    for train_key in simulated_demands[cat]:
        # Last date of training data for this split
        train_df = seasonality_results[cat][train_key]["deseasonalized_train"]
        last_train_date = train_df.index[-1]

        # Forecast horizon (5 weeks)
        forecast_len = len(simulated_demands[cat][train_key]["forecast_mean"])
        forecast_dates = [last_train_date + pd.Timedelta(weeks=i) for i in range(1, forecast_len + 1)]

        # Forecast summary
        forecast_mean = simulated_demands[cat][train_key]["forecast_mean"]
        lower_bound = simulated_demands[cat][train_key]["lower_bound"]
        upper_bound = simulated_demands[cat][train_key]["upper_bound"]

        for i, date in enumerate(forecast_dates):
            export_rows.append({
                "category": cat,
                "year": date.isocalendar().year,
                "week_number": date.isocalendar().week,
                "date": date,
                "actual_quantity": actual_series.get(date, None),
                "monte_carlo_forecast": forecast_mean[i],
                "forecast_p10": lower_bound[i],
                "forecast_p90": upper_bound[i]
            })

# Build DataFrame
export_df = pd.DataFrame(export_rows)

# Sort for clarity
export_df = export_df.sort_values(by=["category", "year", "week_number"]).reset_index(drop=True)

# Export to Excel
output_file = "Amazon_MCRxML.xlsx"
export_df.to_excel(output_file, index=False)

print(f"✅ Results exported to {output_file}")
# Out:
# Exporting results for: Appliances
# Exporting results for: Beauty & Grooming
# Exporting results for: Books
# Exporting results for: Computing
# Exporting results for: Entertainment
# Exporting results for: Health & Sports
# Exporting results for: Home & Living
# Exporting results for: Kids & Baby
# Exporting results for: Men's Fashion
# Exporting results for: Mobiles & Tablets
# Exporting results for: Others
# Exporting results for: School & Education
# Exporting results for: Soghaat
# Exporting results for: Superstore
# Exporting results for: Women's Fashion
# ✅ Results exported to Amazon_MCRxML.xlsx

# %% [markdown]
# ## Data Analysis Part

# %% [markdown]
# ### Scenario Analysis

# %%
import pandas as pd
import numpy as np

# Load forecast output (from your simulation export)
export_df = pd.read_excel("Amazon_MCRxML.xlsx")

# Define scenarios (percentage change in demand)
scenarios = {
    "Lockdown_80": -0.80,
    "Drop_50":    -0.50,
    "Drop_30":    -0.30
}

def apply_shock(series, pct_change):
    """Apply a multiplicative demand shock to a series."""
    return series * (1 + pct_change)

scenario_results = []

for scen_name, shock_pct in scenarios.items():
    # Apply shock to actual quantities
    export_df["actual_shocked"] = apply_shock(export_df["actual_quantity"], shock_pct)
    
    # Compute metrics for shocked scenario
    coverage = np.mean(
        (export_df["actual_shocked"] >= export_df["forecast_p10"]) & 
        (export_df["actual_shocked"] <= export_df["forecast_p90"])
    )
    
    mae = np.mean(np.abs(export_df["forecast_p10"] - export_df["actual_shocked"]))
    
    scenario_results.append({
        "Scenario": scen_name,
        "Coverage_Probability": coverage,
        "MAE": mae
    })

scenario_df = pd.DataFrame(scenario_results)
print(scenario_df)
# Out:
#       Scenario  Coverage_Probability          MAE
# 0  Lockdown_80              0.893333   743.803262
# 1      Drop_50              0.904762  1042.201108
# 2      Drop_30              0.899048  1248.638567

# %% [markdown]
# ### Coverage Probability

# %%
# Coverage Probability in original forecast
coverage_prob = np.mean(
    (export_df["actual_quantity"] >= export_df["forecast_p10"]) & 
    (export_df["actual_quantity"] <= export_df["forecast_p90"])
)
print(f"Coverage Probability (Base Case): {coverage_prob:.2%}")
# Out:
# Coverage Probability (Base Case): 84.38%

# %% [markdown]
# ### Business Savings Estimation

# %%
import pandas as pd
import numpy as np

# Load your forecast export (from your Monte Carlo run)
export_df = pd.read_excel("Amazon_MCRxML.xlsx")
export_df.columns = export_df.columns.str.lower()

# Assumed unit price per category — updated to match YOUR categories exactly
ASSUMED_PRICE = {
    "Appliances": 180.0,
    "Beauty & Grooming": 20.0,
    "Books": 15.0,
    "Computing": 250.0,
    "Entertainment": 25.0,
    "Health & Sports": 50.0,
    "Home & Living": 60.0,
    "Kids & Baby": 35.0,
    "Men's Fashion": 45.0,
    "Mobiles & Tablets": 400.0,
    "Others": 30.0,
    "School & Education": 20.0,
    "Soghaat": 80.0,
    "Superstore": 40.0,
    "Women's Fashion": 55.0,
}

# Fallback price if any category is missing
FALLBACK_PRICE = 30.0

# Map unit prices
export_df["unit_price"] = export_df["category"].map(ASSUMED_PRICE).fillna(FALLBACK_PRICE)

# Keep only the fields we need
base = export_df.dropna(subset=["actual_quantity", "monte_carlo_forecast", "forecast_p10", "forecast_p90"]).copy()

# Define cost parameters
holding_cost_per_unit = 2.0   # cost of holding one unit in stock
stockout_cost_per_unit = 5.0  # penalty for not having enough stock

# Calculate over-forecast (overstock) and under-forecast (stockout)
base["overstock_units"] = np.where(base["monte_carlo_forecast"] > base["actual_quantity"],
                                   base["monte_carlo_forecast"] - base["actual_quantity"], 0)
base["stockout_units"] = np.where(base["monte_carlo_forecast"] < base["actual_quantity"],
                                  base["actual_quantity"] - base["monte_carlo_forecast"], 0)

# Costs in monetary terms
base["overstock_cost"] = base["overstock_units"] * holding_cost_per_unit
base["stockout_cost"] = base["stockout_units"] * stockout_cost_per_unit

# Revenue potential if forecast matches actual demand exactly
base["revenue_if_perfect"] = base["actual_quantity"] * base["unit_price"]

# Revenue loss from stockouts
base["lost_revenue_from_stockouts"] = base["stockout_units"] * base["unit_price"]

# Total potential savings = avoiding stockouts + avoiding overstock costs
total_savings = base["overstock_cost"].sum() + base["lost_revenue_from_stockouts"].sum()

print("=== Business Savings Estimation ===")
print(f"Total Overstock Cost: ${base['overstock_cost'].sum():,.2f}")
print(f"Total Stockout Cost (in penalties): ${base['stockout_cost'].sum():,.2f}")
print(f"Total Lost Revenue from Stockouts: ${base['lost_revenue_from_stockouts'].sum():,.2f}")
print(f"Estimated Potential Savings: ${total_savings:,.2f}")
# Out:
# === Business Savings Estimation ===
# Total Overstock Cost: $494,702.44
# Total Stockout Cost (in penalties): $1,184,806.77
# Total Lost Revenue from Stockouts: $18,750,308.45
# Estimated Potential Savings: $19,245,010.90

# %% [markdown]
# ### Savings Breakdown Pie Chart

# %%
import matplotlib.pyplot as plt

cost_breakdown = {
    "Overstock Cost": base["overstock_cost"].sum(),
    "Lost Revenue from Stockouts": base["lost_revenue_from_stockouts"].sum()
}

plt.figure(figsize=(6,6))
plt.pie(cost_breakdown.values(), labels=cost_breakdown.keys(),
        autopct='%1.1f%%', startangle=140, colors=["#66b3ff", "#ff9999"])
plt.title("Business Savings Breakdown")
plt.show()

# %% [markdown]
# ### Category-Wise Savings Bar Chart

# %%
category_savings = base.groupby("category").apply(
    lambda x: x["overstock_cost"].sum() + x["lost_revenue_from_stockouts"].sum()
).sort_values(ascending=False)

plt.figure(figsize=(10,5))
category_savings.plot(kind="bar", color="skyblue")
plt.ylabel("Potential Savings ($)")
plt.title("Potential Savings by Category")
plt.xticks(rotation=45, ha="right")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
